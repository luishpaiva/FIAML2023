# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Embedding
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences

# %%
from google.colab import files
files.upload()

# %%
spam = pd.read_csv("spam.csv")
spam.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
spam.shape
# Out:
# (5572, 2)

# %%
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(spam['Category'])
print(y)
# Out:
# [0 0 1 ... 0 0 0]

# %%
mensagens = spam['Message'].values
X_train, X_test, y_train, y_test = train_test_split(mensagens, y, test_size = 0.3)

# %%
token = Tokenizer(num_words = 1000)
token.fit_on_texts(X_train)
X_train = token.texts_to_sequences(X_train)
X_test = token.texts_to_sequences(X_test)

# %%
print(X_train)
# Out:
# [[], [86, 305, 1, 35, 16, 3, 145], [70, 4, 30, 359, 41, 491, 518, 735, 35, 31, 944, 17, 15, 4, 868, 736, 2, 737, 9, 5], [5, 492, 869, 29, 40, 39], [314, 38, 82, 76, 349, 206, 41, 161, 945, 22, 91], [70, 9, 44, 44], [94, 52, 34, 1, 36, 466, 2, 31, 179, 28, 18, 4, 124, 405, 804], [604, 870, 34, 20, 394, 2, 350, 4, 637, 33, 3, 18, 4, 100, 16, 132, 429, 430], [50, 87, 395, 77, 9, 638], [1, 186, 1, 92, 18, 95, 140], [243, 1, 871, 21, 72, 10, 45, 290, 228], [60, 4, 322, 40, 39, 40, 39, 159, 40, 39], [1, 153, 14, 162, 446, 10, 2, 52], [3, 18, 114, 394, 2, 540, 9, 115, 15, 639, 12, 315, 265, 640, 637, 2, 132, 16], [180, 872, 872], [53, 69, 3, 291, 227, 104], [305, 685, 377, 47, 16, 10], [86, 1, 186, 72, 149, 686, 96, 3, 9], [86, 76, 16, 104], [447, 3, 10, 7, 49, 13, 9, 57, 227, 33, 3], [316, 56, 106, 946, 4, 566, 26, 252, 104], [20, 3, 9, 406], [333, 317, 407, 1, 35, 13, 378, 9, 641, 873], [24, 4, 351, 116, 805, 121, 806, 174, 8, 29, 95, 7, 8, 448, 687, 36, 10, 7, 9, 29, 5, 46, 18, 3, 114], [305, 1, 61, 231, 12, 13, 16, 377, 47, 100, 16, 10], [6, 83, 4, 738, 6, 114, 394, 22, 350, 431, 170, 26, 4, 41, 265, 396, 2, 4, 266, 807, 22, 132, 221, 285], [808, 179], [244, 125, 116, 2, 191, 24, 323, 166, 334, 27, 3, 32, 121, 9, 58, 125, 519], [73, 408, 7, 19, 244, 520, 150, 126, 493, 872], [73, 15, 261, 9, 947, 467, 1, 874, 93, 57, 11, 739, 11, 253, 24, 57, 22, 30, 222, 21, 69, 197, 740], [275, 121, 25, 1, 7, 7, 397, 360, 36, 335, 1, 276, 306, 17, 25, 1, 409, 13, 229, 8, 379, 21, 14, 92], [18, 4, 56, 352], [6, 51, 46, 2, 688, 12, 4, 686, 9, 11, 686], [100, 134, 65, 4, 40, 494, 39, 519, 686, 12, 10, 1, 57, 227, 49, 5, 69, 7, 35, 31, 12], [122, 101, 232, 118, 3, 20, 324, 4, 56, 948], [137, 25, 1, 93, 185, 1, 82, 3, 410, 407], [122, 101, 232, 46, 20, 3, 129, 20, 3, 45, 20, 42, 875], [398, 134, 317, 33, 42, 175, 110, 44, 48, 212, 229, 9, 58, 125, 519], [1, 93, 68, 2, 432, 213], [949, 194, 567, 22, 5, 34, 521, 689, 6], [21, 568, 3, 59, 125, 4, 9, 89, 214, 254, 89, 214, 121, 19], [6, 255, 138, 98, 876, 73, 1, 433, 522, 89, 99, 198, 69, 6, 99, 23, 741, 336, 23, 605, 24, 569, 59, 74, 30, 337], [10, 24, 44, 570, 41, 9, 5, 495], [166, 11, 143, 337, 361, 256, 468, 87, 6, 571, 690, 361, 52, 87, 38, 262, 229, 2, 52, 325], [7, 174, 49, 42, 8, 449, 6, 7, 1, 65], [38, 950, 118, 215, 107, 18, 4, 496, 29], [263, 8, 541, 64, 380, 8, 541, 83, 541, 497, 149, 146, 8, 541, 742, 23, 31, 9, 691, 56, 113, 149, 353, 497], [1, 61, 29, 4, 951, 34], [1, 35, 31, 407, 42, 35, 151, 353, 64], [37, 85, 11, 64, 33, 13, 81, 952, 450], [743, 51, 1, 141, 128], [167, 1, 68, 14, 2, 31, 13, 237], [411, 692, 83], [451, 338, 326, 744, 195, 47, 26, 498, 233, 75, 17, 381, 16, 606, 17, 607, 26, 809], [134, 106, 452, 42, 44, 7, 162, 98, 20, 84, 2], [47, 12, 327, 106, 195, 207, 41, 30, 523, 159, 106, 36, 75, 195, 2, 693, 32, 877, 7, 111, 30, 810, 156, 245, 208, 642, 207, 223], [275, 70, 9, 469, 572], [38, 167, 1, 270, 875, 4, 307, 25, 1, 277, 1, 608, 4, 73], [83, 811, 25, 745, 8, 24, 4, 811, 398, 73, 15, 5, 878, 71, 398, 21, 40, 39, 15, 246, 8, 9, 209, 27, 31, 879, 12, 12, 40, 39, 27, 135, 40, 39, 2, 49, 48, 102, 2, 41, 47, 2, 126, 354, 40, 39, 159, 27, 32, 40, 39, 12, 40, 39, 38, 82, 15, 453, 878, 149, 953, 117, 46, 98, 246, 8, 74, 42, 18, 643, 880, 745, 411, 412], [23, 53, 28, 3, 328, 28], [74, 5, 136, 8, 2, 163, 224, 93], [86, 76, 16, 104], [454, 1, 139, 31, 66, 74, 470, 29, 5, 326, 413, 2, 298, 20, 7, 227, 26, 139, 42, 36, 28, 399], [60, 4, 694, 67, 382, 141, 2, 49, 30, 238, 33, 199, 83, 130, 275, 62, 189, 160, 6, 209, 542, 10, 5, 261], [20, 3, 278, 56, 414], [94, 396, 2, 21, 216], [35, 105, 56, 185, 15, 3], [93, 3, 18, 142, 338], [543, 573, 34, 4, 947, 574, 189, 446, 4, 447, 46, 8, 30, 146, 71, 149, 89, 8, 254], [65, 377, 62, 166, 267, 49, 471], [1, 32, 54, 15, 339, 9, 9, 58, 40, 39, 434, 3, 51, 129, 8], [340, 78, 1, 217, 128, 2, 32, 126], [25, 13, 644, 65, 40, 39, 40, 39, 435], [6, 1, 1, 292, 6, 184, 16], [37, 609, 567, 59, 17, 954, 103, 41, 362, 87, 243, 1, 133, 35, 52, 69], [62, 77, 1 ...

# %%
X_train = pad_sequences(X_train, padding = "post", maxlen = 500)
X_test = pad_sequences(X_test, padding = "post", maxlen = 500)

# %%
len(token.word_index)
# Out:
# 7393

# %%
X_train
# Out:
# array([[  0,   0,   0, ...,   0,   0,   0],
#        [ 86, 305,   1, ...,   0,   0,   0],
#        [ 70,   4,  30, ...,   0,   0,   0],
#        ...,
#        [  1,  61,  24, ...,   0,   0,   0],
#        [765,  41, 265, ...,   0,   0,   0],
#        [124,  18,   4, ...,   0,   0,   0]], dtype=int32)

# %%
token.word_index

# %%
modelo = Sequential()
modelo.add(Embedding(input_dim = len(token.word_index), output_dim = 50, input_length = 500))
modelo.add(Flatten())
modelo.add(Dense(units = 10, activation = 'relu'))
modelo.add(Dropout(0.1))
modelo.add(Dense(units = 1, activation = 'sigmoid'))

# %%
modelo.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ["accuracy"])

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 50)           369650
#
#  flatten (Flatten)           (None, 25000)             0
#
#  dense (Dense)               (None, 10)                250010
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 619671 (2.36 MB)
# Trainable params: 619671 (2.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
modelo.fit(X_train, y_train, epochs = 20, batch_size = 10, verbose = True, validation_data = (X_test, y_test))
# Out:
# Epoch 1/20
# 390/390 [==============================] - 5s 11ms/step - loss: 0.0958 - accuracy: 0.8667 - val_loss: 0.0527 - val_accuracy: 0.8624
# Epoch 2/20
# 390/390 [==============================] - 4s 11ms/step - loss: 0.0633 - accuracy: 0.8738 - val_loss: 0.0460 - val_accuracy: 0.9785
# Epoch 3/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0605 - accuracy: 0.9013 - val_loss: 0.0442 - val_accuracy: 0.9731
# Epoch 4/20
# 390/390 [==============================] - 4s 11ms/step - loss: 0.0562 - accuracy: 0.9113 - val_loss: 0.0405 - val_accuracy: 0.9767
# Epoch 5/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0541 - accuracy: 0.9151 - val_loss: 0.0389 - val_accuracy: 0.9767
# Epoch 6/20
# 390/390 [==============================] - 4s 11ms/step - loss: 0.0545 - accuracy: 0.9115 - val_loss: 0.0368 - val_accuracy: 0.9821
# Epoch 7/20
# 390/390 [==============================] - 4s 10ms/step - loss: 0.0579 - accuracy: 0.9008 - val_loss: 0.0362 - val_accuracy: 0.9844
# Epoch 8/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0533 - accuracy: 0.9136 - val_loss: 0.0374 - val_accuracy: 0.9785
# Epoch 9/20
# 390/390 [==============================] - 5s 13ms/step - loss: 0.0560 - accuracy: 0.9051 - val_loss: 0.0367 - val_accuracy: 0.9791
# Epoch 10/20
# 390/390 [==============================] - 4s 10ms/step - loss: 0.0513 - accuracy: 0.9187 - val_loss: 0.0345 - val_accuracy: 0.9833
# Epoch 11/20
# 390/390 [==============================] - 7s 17ms/step - loss: 0.0544 - accuracy: 0.9100 - val_loss: 0.0350 - val_accuracy: 0.9815
# Epoch 12/20
# 390/390 [==============================] - 4s 11ms/step - loss: 0.0449 - accuracy: 0.9377 - val_loss: 0.0347 - val_accuracy: 0.9809
# Epoch 13/20
# 390/390 [==============================] - 4s 10ms/step - loss: 0.0231 - accuracy: 0.9890 - val_loss: 0.0314 - val_accuracy: 0.9797
# Epoch 14/20
# 390/390 [==============================] - 6s 15ms/step - loss: 0.0176 - accuracy: 0.9928 - val_loss: 0.0287 - val_accuracy: 0.9803
# Epoch 15/20
# 390/390 [==============================] - 4s 11ms/step - loss: 0.0176 - accuracy: 0.9877 - val_loss: 0.0259 - val_accuracy: 0.9803
# Epoch 16/20
# 390/390 [==============================] - 4s 11ms/step - loss: 0.0096 - accuracy: 0.9908 - val_loss: 0.0168 - val_accuracy: 0.9821
# Epoch 17/20
# 390/390 [==============================] - 7s 19ms/step - loss: 0.0028 - accuracy: 0.9972 - val_loss: 0.0166 - val_accuracy: 0.9827
# Epoch 18/20
# 390/390 [==============================] - 4s 11ms/step - loss: 0.0022 - accuracy: 0.9974 - val_loss: 0.0173 - val_accuracy: 0.9815
# Epoch 19/20
# 390/390 [==============================] - 5s 13ms/step - loss: 0.0016 - accuracy: 0.9982 - val_loss: 0.0169 - val_accuracy: 0.9833
# Epoch 20/20
# 390/390 [==============================] - 4s 11ms/step - loss: 0.0025 - accuracy: 0.9967 - val_loss: 0.0180 - val_accuracy: 0.9809

# %%
loss, accuracy = modelo.evaluate(X_test, y_test)
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0180 - accuracy: 0.9809
# Loss:  0.01796841248869896
# Accuracy:  0.980861246585846

# %%
nova_previsao = modelo.predict(X_test)
print(nova_previsao)
# Out:
# 53/53 [==============================] - 0s 5ms/step
# [[1.2539088e-10]
#  [8.8850585e-13]
#  [6.9082930e-14]
#  ...
#  [4.3877853e-15]
#  [4.6594495e-10]
#  [1.9234776e-07]]

# %%
prev = (nova_previsao > 0.5)
print(prev)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
cm = confusion_matrix(y_test, prev)
print(cm)
# Out:
# [[1442    0]
#  [  32  198]]

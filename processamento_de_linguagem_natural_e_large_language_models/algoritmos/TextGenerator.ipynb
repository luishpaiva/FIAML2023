# %%
# !pip install transformers

# %%
import transformers
from transformers import pipeline

# %%
gerador = pipeline("text-generation", model = "pierreguillou/gpt2-small-portuguese")
texto = "Em sentido estrito, ciência refere-se ao sistema de adquirir conhecimento baseado no método científico"
resultado = gerador(texto, max_length = 100, do_sample = True)
print(resultado)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/510M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/92.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/850k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/508k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Em sentido estrito, ciência refere-se ao sistema de adquirir conhecimento baseado no método científico, mas a palavra "ciência" deve ser compreendida com distinção. Segundo Michael Will, "Na filosofia, o método científico é o processo de verificar, a partir de um princípio científico, o que é considerado como conhecimento."\n\nUm exemplo bastante claro da ideia de "ciência" de Will é o sistema de crença, em oposição à crença de que uma teoria científica é verdadeira. Se qualquer cientista fosse capaz de demonstrar'}]

# %%
texto = "Um transformers é um grande modelo de linguagem natural"
resultado = gerador(texto, max_length = 100, do_sample = True)
print(resultado)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Um transformers é um grande modelo de linguagem natural.\n\nEm contraste com outras estruturas algébricas de linguagens natural, existem linguagens de programação que podem ser escritas e executadas. Muitos desses tipos são puramente declarados.\n\n\nQuando um programa de computador converte um sinal de saída em um identificador de forma recursiva, um processo de programação onde todas as portas de entrada para ser interpretadas são abertas, e termina em um programa escrito (ou a partir), um programa escrito que, em seguida,'}]
